# %%
import pandas as pd 
import numpy as np

# %%
my_schedule = pd.read_excel('a44.xlsx')

# %%
my_schedule
# Out:
#       شماره درس  گروه درس                          نام درس  واحد  \
# 0     1212122.0       2.0          سير عقايد و آراي اسلامي   2.0
# 1     1212122.0       1.0          سير عقايد و آراي اسلامي   2.0
# 2     1212122.0       2.0          سير عقايد و آراي اسلامي   2.0
# 3     1212132.0       1.0                     عروض و قافيه   2.0
# 4     1212148.0       1.0  تحقيق در ادبيات حماسي و قهرماني   2.0
# ...         ...       ...                              ...   ...
# 3087  4214226.0       1.0      مباحث ويژه در گداخت هسته‌اي   3.0
# 3088  4214226.0       1.0      مباحث ويژه در گداخت هسته‌اي   3.0
# 3089  4214244.0       1.0   روش هاي آناليز هسته اي پيشرفته   3.0
# 3090  4214244.0       1.0   روش هاي آناليز هسته اي پيشرفته   3.0
# 3091        NaN       NaN                              NaN   NaN
#
#      روز ارائه درس   Unnamed: 5  مقطع درس   ساعت مجازی  کد ساعت دانشکده  \
# 0          دو شنبه  14:00-16:00      ارشد  14:30-15:30      7.0  ادبیات
# 1          سه شنبه  10:30-12:30      ارشد  10:00-11:00      3.0  ادبیات
# 2             جمعه  14:00-16:00      ارشد  09:00-10:00      2.0  ادبیات
# 3          دو شنبه  10:30-12:30  کارشناسی  10:00-11:00      3.0  ادبیات
# 4             شنبه  14:00-16:00     دکتری  20:30-21:30     13.0  ادبیات
# ...            ...          ...       ...          ...      ...     ...
# 3087       پنجشنبه  15:00-16:00     دکتری  15:30-16:30      8.0   فیزیک
# 3088       سه شنبه  10:00-12:00     دکتری  20:30-21:30     13.0   فیزیک
# 3089          شنبه  10:00-12:00     دکتری  20:30-21:30     13.0   فیزیک
# 3090       دو شنبه  15:00-16:00     دکتری  15:30-16:30      8.0   فیزیک
# 3091           NaN          NaN       NaN          NaN      NaN     NaN
#
#                            استاد Unnamed: 11
# 0                    احسان رئيسي           1
# 1       الهام سيدان قلعه جوزداني           1
# 2                    احسان رئيسي         NaN
# 3          حسين آقاحسيني دهاقاني           1
# 4          اسحاق طغياني اسفرجاني           .
# ...                          ...         ...
# 3087            محمد علي عسگريان           3
# 3088      392209علي عسگريان محمد           3
# 3089        بابك شيراني بيدآبادي           3
# 3090  302364شيراني بيدآبادي بابك           3
# 3091                         NaN       تعداد
#
# [3092 rows x 12 columns]

# %%
my_schedule.columns
# Out:
# Index(['شماره درس', 'گروه درس', 'نام درس', 'واحد', 'روز ارائه درس',
#        'Unnamed: 5', 'مقطع درس', 'ساعت مجازی', 'کد ساعت', 'دانشکده', 'استاد',
#        'Unnamed: 11'],
#       dtype='object')

# %%
my_schedule.drop(['Unnamed: 5','Unnamed: 11'],axis=1,inplace=True)

# %%
my_schedule
# Out:
#       شماره درس  گروه درس                          نام درس  واحد  \
# 0     1212122.0       2.0          سير عقايد و آراي اسلامي   2.0
# 1     1212122.0       1.0          سير عقايد و آراي اسلامي   2.0
# 2     1212122.0       2.0          سير عقايد و آراي اسلامي   2.0
# 3     1212132.0       1.0                     عروض و قافيه   2.0
# 4     1212148.0       1.0  تحقيق در ادبيات حماسي و قهرماني   2.0
# ...         ...       ...                              ...   ...
# 3087  4214226.0       1.0      مباحث ويژه در گداخت هسته‌اي   3.0
# 3088  4214226.0       1.0      مباحث ويژه در گداخت هسته‌اي   3.0
# 3089  4214244.0       1.0   روش هاي آناليز هسته اي پيشرفته   3.0
# 3090  4214244.0       1.0   روش هاي آناليز هسته اي پيشرفته   3.0
# 3091        NaN       NaN                              NaN   NaN
#
#      روز ارائه درس  مقطع درس   ساعت مجازی  کد ساعت دانشکده  \
# 0          دو شنبه      ارشد  14:30-15:30      7.0  ادبیات
# 1          سه شنبه      ارشد  10:00-11:00      3.0  ادبیات
# 2             جمعه      ارشد  09:00-10:00      2.0  ادبیات
# 3          دو شنبه  کارشناسی  10:00-11:00      3.0  ادبیات
# 4             شنبه     دکتری  20:30-21:30     13.0  ادبیات
# ...            ...       ...          ...      ...     ...
# 3087       پنجشنبه     دکتری  15:30-16:30      8.0   فیزیک
# 3088       سه شنبه     دکتری  20:30-21:30     13.0   فیزیک
# 3089          شنبه     دکتری  20:30-21:30     13.0   فیزیک
# 3090       دو شنبه     دکتری  15:30-16:30      8.0   فیزیک
# 3091           NaN       NaN          NaN      NaN     NaN
#
#                            استاد
# 0                    احسان رئيسي
# 1       الهام سيدان قلعه جوزداني
# 2                    احسان رئيسي
# 3          حسين آقاحسيني دهاقاني
# 4          اسحاق طغياني اسفرجاني
# ...                          ...
# 3087            محمد علي عسگريان
# 3088      392209علي عسگريان محمد
# 3089        بابك شيراني بيدآبادي
# 3090  302364شيراني بيدآبادي بابك
# 3091                         NaN
#
# [3092 rows x 10 columns]

# %%
my_schedule.drop(3091,inplace=True)
my_schedule[my_schedule['شماره درس'].isnull()]
# Out:
# Empty DataFrame
# Columns: [شماره درس, گروه درس, نام درس, واحد, روز ارائه درس, مقطع درس, ساعت مجازی, کد ساعت, دانشکده, استاد]
# Index: []

# %%
my_schedule.loc[:,'شماره درس']= my_schedule[['شماره درس']].astype('int64')
my_schedule.loc[:,'گروه درس']= my_schedule[['گروه درس']].astype('int64')

my_schedule.loc[:,'شماره درس']= my_schedule[['شماره درس']].astype(str)
my_schedule.loc[:,'گروه درس']= my_schedule[['گروه درس']].astype(str)

# %%
def zero_lesson_group (column) :
    if len(column) < 2:
        return '0' + column 
    return column
my_schedule.loc[:,'گروه درس'] = my_schedule['گروه درس'].apply(zero_lesson_group)

# %%
my_schedule[my_schedule['دانشکده']=='مهندسی کامپیوتر']
# Out:
#      شماره درس گروه درس                            نام درس  واحد  \
# 2368   3612014       01                      سمينار معماري   2.0
# 2369   3612151       01    طراحي سيستم هاي تحمل پذير اشكال   3.0
# 2370   3612151       01    طراحي سيستم هاي تحمل پذير اشكال   3.0
# 2371   3612152       01                آزمون و آزمون پذيري   3.0
# 2372   3612152       01                آزمون و آزمون پذيري   3.0
# ...        ...      ...                                ...   ...
# 2570   3620089       01             تعامل انسان و كامپيوتر   3.0
# 2571   3620104       01                    مباني داده كاوي   3.0
# 2572   3620104       01                    مباني داده كاوي   3.0
# 2573   3620105       01  مباني بازيابي اطلاعات و جستجوي وب   3.0
# 2574   3620105       01  مباني بازيابي اطلاعات و جستجوي وب   3.0
#
#      روز ارائه درس  مقطع درس   ساعت مجازی  کد ساعت          دانشکده  \
# 2368          شنبه      ارشد  11:00-12:00      4.0  مهندسی کامپیوتر
# 2369       يك شنبه     دکتری  09:00-10:00      2.0  مهندسی کامپیوتر
# 2370       پنجشنبه     دکتری  09:00-10:00      2.0  مهندسی کامپیوتر
# 2371          شنبه     دکتری  10:00-11:00      3.0  مهندسی کامپیوتر
# 2372       دو شنبه     دکتری  09:00-10:00      2.0  مهندسی کامپیوتر
# ...            ...       ...          ...      ...              ...
# 2570       يك شنبه  کارشناسی  09:00-10:00      2.0  مهندسی کامپیوتر
# 2571     چهار شنبه  کارشناسی  16:30-17:30      9.0  مهندسی کامپیوتر
# 2572          شنبه  کارشناسی  16:30-17:30      9.0  مهندسی کامپیوتر
# 2573       يك شنبه  کارشناسی  11:00-12:00      4.0  مهندسی کامپیوتر
# 2574       سه شنبه  کارشناسی  09:00-10:00      2.0  مهندسی کامپیوتر
#
#                            استاد
# 2368                 مهران رضايي
# 2369        شهرام اعتمادي بروجني
# 2370  301095اعتمادي بروجني شهرام
# 2371        شهرام اعتمادي بروجني
# 2372  301095اعتمادي بروجني شهرام
# ...                          ...
# 2570   392120كلاه دوزرحيمي شكوفه
# 2571                  رضا رمضاني
# 2572            396079رمضاني رضا
# 2573         الهام اسمعيلي گوهري
# 2574   398179اسمعيلي گوهري الهام
#
# [207 rows x 10 columns]

# %%
my_schedule['lesson_id'] = my_schedule['شماره درس'] + my_schedule['گروه درس']

# %%
lesson_ids = []
lesson_ids.append('282207714')
lesson_ids.append('362001802')
lesson_ids.append('362001901')
lesson_ids.append('362002204')
lesson_ids.append('362003102')
lesson_ids.append('362005410')
lesson_ids.append('362005701')
lesson_ids.append('362005801')
lesson_ids.append('362005901')

# %%
temp = my_schedule[my_schedule['lesson_id'].isin(lesson_ids)]

# %%
temp
# Out:
#      شماره درس گروه درس                     نام درس  واحد روز ارائه درس  \
# 2490   3620018       02   ريزپردازنده و زبان اسمبلي   3.0     چهار شنبه
# 2493   3620018       02   ريزپردازنده و زبان اسمبلي   3.0          شنبه
# 2495   3620019       01          شبكه هاي كامپيوتري   3.0          شنبه
# 2497   3620019       01          شبكه هاي كامپيوتري   3.0       دو شنبه
# 2505   3620022       04    آزمايشگاه سيستم هاي عامل   1.0          جمعه
# 2525   3620031       02  آزمايشگاه مهندسي نرم افزار   1.0          جمعه
# 2549   3620057       01              پايگاه داده ها   3.0     چهار شنبه
# 2550   3620057       01              پايگاه داده ها   3.0       پنجشنبه
# 2551   3620058       01  طراحي زبان هاي برنامه سازي   3.0       سه شنبه
# 2553   3620058       01  طراحي زبان هاي برنامه سازي   3.0          جمعه
# 2555   3620059       01            مهندسي نرم افزار   3.0       سه شنبه
# 2556   3620059       01            مهندسي نرم افزار   3.0          جمعه
#
#       مقطع درس   ساعت مجازی  کد ساعت          دانشکده  \
# 2490  کارشناسی  08:00-09:00      1.0  مهندسی کامپیوتر
# 2493  کارشناسی  09:00-10:00      2.0  مهندسی کامپیوتر
# 2495  کارشناسی  11:00-12:00      4.0  مهندسی کامپیوتر
# 2497  کارشناسی  20:30-21:30     13.0  مهندسی کامپیوتر
# 2505  کارشناسی  15:30-16:30      8.0  مهندسی کامپیوتر
# 2525  کارشناسی  12:00-13:00      5.0  مهندسی کامپیوتر
# 2549  کارشناسی  11:00-12:00      4.0  مهندسی کامپیوتر
# 2550  کارشناسی  11:00-12:00      4.0  مهندسی کامپیوتر
# 2551  کارشناسی  16:30-17:30      9.0  مهندسی کامپیوتر
# 2553  کارشناسی  13:30-14:30      6.0  مهندسی کامپیوتر
# 2555  کارشناسی  18:30-19:30     11.0  مهندسی کامپیوتر
# 2556  کارشناسی  18:30-19:30     11.0  مهندسی کامپیوتر
#
#                              استاد  lesson_id
# 2490              حسين ماهوش محمدي  362001802
# 2493        391108ماهوش محمدي حسين  362001802
# 2495                      ندا مقيم  362001901
# 2497                302388مقيم ندا  362001901
# 2505                    مریم طائبی  362002204
# 2525              رجايي ريزي زهرا   362003102
# 2549              محمدعلي نعمت بخش  362005701
# 2550        301104نعمت بخش محمدعلي  362005701
# 2551           مهيار حسن پوركليدسر  362005801
# 2553     397248حسن پوركليدسر مهيار  362005801
# 2555        افسانه فاطمي خوراسگاني  362005901
# 2556  300236فاطمي خوراسگاني افسانه  362005901

# %%
temp.drop(['lesson_id'],axis=1).to_csv('result.csv')
temp.drop(['lesson_id'],axis=1).to_excel('result.xlsx')
